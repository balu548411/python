# %% [markdown]
# # Decorators in Python
#
# *Source: [GeeksforGeeks - Decorators in Python](https://www.geeksforgeeks.org/python/decorators-in-python/)*
#
# In Python, decorators are a flexible way to modify or extend the behavior of functions or methods, without changing their actual code.
#
# - A decorator is essentially a function that takes another function as an argument and returns a new function with enhanced functionality.
# - Decorators are often used in scenarios such as logging, authentication and memorization, allowing us to add additional functionality to existing functions or methods in a clean, reusable way.

# %% [markdown]
# ## Basic Decorator Example
#
# Let's see an example in which a simple Python decorator adds behavior before and after a function call.

# %%
def decorator(func):
    def wrapper():
        print("Before calling the function.")
        func()
        print("After calling the function.")
    return wrapper

@decorator  # Applying the decorator to a function
def greet():
    print("Hello, World!")

greet()

# %% [markdown]
# **Explanation:**
# - `decorator` takes the greet function as an argument.
# - It returns a new function (wrapper) that first prints a message, calls `greet()` and then prints another message.
# - `@decorator` syntax is a shorthand for `greet = decorator(greet)`.

# %% [markdown]
# ## Decorator with Parameters
#
# Decorators often need to work with functions that have arguments. We use `*args` and `**kwargs` so our wrapper can accept any number of arguments.

# %%
def decorator_name(func):
    def wrapper(*args, **kwargs):
        print("Before execution")
        result = func(*args, **kwargs)
        print("After execution")
        return result
    return wrapper

@decorator_name
def add(a, b):
    return a + b

print(add(5, 3))
# Out:
# Before execution
# After execution
# 8

# %% [markdown]
# ### Explanation of Parameters
#
# - `decorator_name(func)`: This is the decorator function. It takes another function (func) as input.
# - `wrapper(*args, **kwargs)`: A nested function that wraps func. `*args` collects positional arguments, `**kwargs` collects keyword arguments, so wrapper works with any function.
# - `@decorator_name`: Syntax sugar for `add = decorator_name(add)`.

# %% [markdown]
# ## Functions as First-Class Objects
#
# In Python, functions are first-class objects, meaning they can be treated like any other object (such as integers, strings or lists). This allows functions to be:
#
# - **assigned to variables**
# - **passed as arguments**
# - **returned from other functions**
# - **stored in data structures**
#
# This enables flexible programming patterns, including decorators.

# %%
# Assigning a function to a variable
def greet(n):
    return f"Hello, {n}!"

say_hi = greet  # Assign the greet function to say_hi
print(say_hi("Alice"))

# Passing a function as an argument
def apply(f, v):
    return f(v)

res = apply(say_hi, "Bob")
print(res)

# Returning a function from another function
def make_mult(f):
    def mult(x):
        return x * f
    return mult

dbl = make_mult(2)
print(dbl(5))
# Out:
# Hello, Alice!
# Hello, Bob!
# 10

# %% [markdown]
# **Explanation:**
# - `greet()` is assigned to `say_hi` variable, which is used to print a greeting for "Alice".
# - `apply()` takes a function and a value as arguments, applies function to value and returns the result.
# - `apply` is demonstrated by passing `say_hi` and "Bob", printing a greeting for "Bob".
# - `make_mult()` creates a multiplier function based on a given factor.
#
# ### Role of First-Class Functions in Decorators
#
# - Decorators take a function as input to modify or enhance its behavior.
# - They return a new function that wraps the original, adding behavior before or after execution.
# - The original function is replaced by decorated function when assigned to same name.

# %% [markdown]
# ## Higher-Order Functions
#
# Higher-order functions are functions that take one or more functions as arguments, return a function as a result or do both. Essentially, a higher-order function is a function that operates on other functions. This is a powerful concept in functional programming and is a key component in understanding how decorators work.
#
# ### Key Properties of Higher-Order Functions
#
# - **Taking functions as arguments**: A higher-order function can accept other functions as parameters.
# - **Returning functions**: A higher-order function can return a new function that can be called later.

# %%
# A higher-order function that takes another function as an argument
def fun(f, x):
    return f(x)

# A simple function to pass
def square(x):
    return x * x

res = fun(square, 5)  # Using apply_function to apply the square function
print(res)
# Out:
# 25

# %% [markdown]
# **Explanation:** `fun` is a higher-order function because it takes another function `f` as an argument and applies it to the value `x`.
#
# ### Role of Higher-Order Functions in Decorators
#
# Decorators are higher-order functions that take a function, modify it and return a new one with extended or altered behavior.

# %% [markdown]
# ## Types of Decorators
#
# ### 1. Function Decorators
#
# The most common decorators in Python, used to wrap and enhance functions by adding extra behavior before or after the original function runs.

# %%
def simple_decorator(func):
    def wrapper():
        print(">>> Starting function")
        func()
        print(">>> Function finished")
    return wrapper

@simple_decorator
def greet():
    print("Hello, World!")

greet()
# Out:
# >>> Starting function
# Hello, World!
# >>> Function finished

# %% [markdown]
# **Explanation:**
# - `simple_decorator(func)`: This decorator takes the function greet as an argument (func) and returns a new function (wrapper) that adds some functionality before and after calling original function.
# - `@simple_decorator`: This is the decorator syntax. It applies simple_decorator to greet function.
# - **Calling greet()**: When greet() is called, it doesn't just execute original function but first runs added behavior from wrapper function.

# %% [markdown]
# ### 2. Method Decorators
#
# Special decorators used for methods inside a class. They work like function decorators but handle the self parameter for instance methods.

# %%
def method_decorator(func):
    def wrapper(self, *args, **kwargs):
        print(">>> Starting method")
        result = func(self, *args, **kwargs)
        print(">>> Method finished")
        return result
    return wrapper

class MyClass:
    @method_decorator
    def my_method(self, value):
        print(f"Processing: {value}")
        return value * 2

obj = MyClass()
result = obj.my_method(5)
print(f"Result: {result}")
# Out:
# >>> Starting method
# Processing: 5
# >>> Method finished
# Result: 10

# %% [markdown]
# **Explanation:**
# - `method_decorator(func)`: This decorator takes a method as an argument and returns a new function (wrapper) that adds functionality before and after calling the original method.
# - `wrapper(self, *args, **kwargs)`: The wrapper function properly handles the `self` parameter and any additional arguments.
# - `@method_decorator`: This applies the decorator to the `my_method` method.

# %% [markdown]
# ### 3. Class Decorators
#
# Class decorators are used to modify or enhance classes. They take a class as an argument and return a modified class.

# %%
def add_class_name(cls):
    cls.class_name = "person class"
    return cls

@add_class_name
class Person:
    def __init__(self, name):
        self.name = name

person = Person("Alice")
print(f"Person name: {person.name}")
print(f"Class name: {Person.class_name}")
# Out:
# Person name: Alice
# Class name: person class

# %% [markdown]
# **Explanation:**
# - `add_class_name(cls)`: This decorator adds a new attribute, `class_name`, to class `cls`. The value of `class_name` is set to the name of class (`cls.__name__`).
# - `@add_class_name`: This applies the `add_class_name` decorator to the `Person` class.

# %% [markdown]
# ## Built-in Decorators
#
# Python provides several built-in decorators that are used in class definitions. These decorators modify behavior of methods and attributes in a class, making it easier to manage and use them effectively. The most frequently used built-in decorators are `@staticmethod`, `@classmethod` and `@property`.

# %% [markdown]
# ### @staticmethod
#
# It is used to define a method that doesn't operate on an instance of class (i.e., it doesn't use self). Static methods are called on class itself, not on an instance of class.

# %%
class MathOperations:
    @staticmethod
    def add(x, y):
        return x + y

# Using the static method
res = MathOperations.add(5, 3)
print(res)
# Out:
# 8

# %% [markdown]
# **Explanation:**
# - `add` is a static method defined with `@staticmethod` decorator.
# - It can be called directly on class `MathOperations` without creating an instance.

# %% [markdown]
# ### @classmethod
#
# It is used to define a method that operates on class itself (i.e., it uses cls). Class methods can access and modify class state that applies across all instances of class.

# %%
class Employee:
    raise_amount = 1.05
    
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
        
    @classmethod
    def set_raise_amount(cls, amount):
        cls.raise_amount = amount

# Using the class method
Employee.set_raise_amount(1.10)
print(Employee.raise_amount)
# Out:
# 1.1

# %% [markdown]
# **Explanation:**
# - `set_raise_amount` is a class method defined with `@classmethod` decorator.
# - It can modify class variable `raise_amount` for class Employee and all its instances.

# %% [markdown]
# ### @property
#
# It is used to define a method as a property, which allows you to access it like an attribute. This is useful for encapsulating implementation of a method while still providing a simple interface.

# %%
class Circle:
    def __init__(self, radius):
        self._radius = radius

    @property
    def radius(self):
        return self._radius

    @radius.setter
    def radius(self, value):
        if value >= 0:
            self._radius = value
        else:
            raise ValueError("Radius cannot be negative")

    @property
    def area(self):
        return 3.14159 * (self._radius ** 2)

# Using the property
c = Circle(5)
print(c.radius)
print(c.area)
c.radius = 10
# Out:
# 5
# 78.53975

# %% [markdown]
# **Explanation:**
# - `radius` and `area` are properties defined with `@property` decorator.
# - `radius` property also has a `setter` method to allow modification with validation.
# - These properties provide a way to access and modify private attributes while maintaining encapsulation.

# %% [markdown]
# ## Chaining Multiple Decorators
#
# Chaining decorators means applying multiple decorators to same function. Each decorator wraps function in sequence, adding layered behavior.

# %%
def decor1(func): 
    def inner(): 
        x = func() 
        return x * x 
    return inner 

def decor(func): 
    def inner(): 
        x = func() 
        return 2 * x 
    return inner 

@decor1
@decor
def num(): 
    return 10

@decor
@decor1
def num2():
    return 10

print(num()) 
print(num2())
# Out:
# 400
# 200

# %% [markdown]
# **Explanation:**
# - In `num()`, `decor` runs first -> 10 becomes 20, then `decor1` squares it -> 400.
# - In `num2()`, `decor1` runs first -> 10 becomes 100, then `decor` doubles it -> 200.

# %% [markdown]
# ## Real-World Uses of Decorators
#
# 1. **Logging**: Track function calls (e.g., @logger).
# 2. **Authentication**: Restrict access in web apps (e.g., Flask/Django).
# 3. **Rate Limiting**: Control API usage per user.
# 4. **Caching**: Store results using functools.lru_cache.
# 5. **Retry Logic**: Automatically retry failed network calls.
#
# ---
#
# *This notebook contains comprehensive information about Python decorators based on the GeeksforGeeks tutorial. Decorators are a powerful feature that allows you to modify or extend the behavior of functions and methods in a clean, reusable way.*

# %% [markdown]
# # Tasks and Homework
#
# ## Practice Tasks
#
# ### Task 1: Basic Decorators
# Create simple decorators for common functionality:
# - `@timer` - measures and displays function execution time
# - `@logger` - logs function calls with parameters and return values
# - `@retry` - retries function execution on failure
# - `@validate_input` - validates function input parameters
# - `@cache_result` - caches function results to avoid recomputation
#
# ### Task 2: Function Enhancement Decorators
# Build decorators that enhance function behavior:
# - `@deprecated` - marks functions as deprecated with warnings
# - `@rate_limit` - limits function call frequency
# - `@authenticate` - adds authentication to functions
# - `@authorize` - adds authorization checks to functions
# - `@audit` - creates audit trails for function calls
#
# ### Task 3: Advanced Decorator Patterns
# Implement complex decorator patterns:
# - `@singleton` - ensures only one instance of a class
# - `@property` - creates property-like behavior for methods
# - `@staticmethod` and `@classmethod` - creates static and class methods
# - `@contextmanager` - creates context managers
# - `@wraps` - preserves function metadata when decorating
#
# ## Homework Assignment
#
# ### Assignment: Advanced Function Enhancement System with Decorators
# Create a comprehensive system that uses decorators to enhance function behavior and implement advanced programming patterns.
#
# **Requirements:**
#
# 1. **Core Decorator Library:**
#    - `@performance_monitor` - monitors function performance and resource usage
#    - `@security_check` - adds security validation to functions
#    - `@data_validation` - validates input and output data
#    - `@error_handling` - provides comprehensive error handling
#    - `@logging` - creates detailed function execution logs
#
# 2. **Advanced Decorator Features:**
#    - **Parameterized Decorators:**
#      - Decorators that accept configuration parameters
#      - Dynamic behavior based on decorator arguments
#      - Conditional functionality based on environment
#
#    - **Decorator Chaining:**
#      - Multiple decorators working together
#      - Order-dependent decorator behavior
#      - Composable decorator patterns
#
#    - **Class Decorators:**
#      - Decorators that modify entire classes
#      - Method-level enhancements
#      - Class-level behavior modification
#
# **Implementation Guidelines:**
# - Use `functools.wraps` to preserve function metadata
# - Implement proper error handling in decorators
# - Create reusable and composable decorators
# - Use type hints for better code documentation
# - Test decorators with various function signatures
# - Document decorator behavior and parameters
#
# **Submission Requirements:**
# - Save your code in a file named `decorator_system.py`
# - Include all decorator implementations
# - Create comprehensive examples of decorator usage
# - Include unit tests for all decorators
# - Document decorator behavior and parameters
